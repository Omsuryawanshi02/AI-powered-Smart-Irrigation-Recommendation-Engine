# %%
import os
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from xgboost import XGBRegressor
import joblib

warnings.filterwarnings("ignore")

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
DATA_PATH = "../data/irrigation_prediction.csv"

df = pd.read_csv(DATA_PATH)

print("Dataset loaded successfully!")
print("Shape:", df.shape)

display(df.head())
# Out:
# Dataset loaded successfully!
# Shape: (10000, 20)
#   Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  Electrical_Conductivity  \
# 0      Clay     6.14          36.48            0.42                     2.17
# 1      Silt     6.41          50.56            0.38                     0.23
# 2     Sandy     7.71          40.07            1.09                     2.18
# 3      Clay     5.96          12.75            1.56                     0.40
# 4      Clay     7.76          18.58            0.95                     2.52
#
#    Temperature_C  Humidity  Rainfall_mm  Sunlight_Hours  Wind_Speed_kmh  \
# 0          21.90     31.19      1167.70            4.01            1.97
# 1          36.50     26.01       831.28           10.72           16.82
# 2          41.83     76.41      1844.45            7.75           19.03
# 3          37.22     43.32       306.26            8.90           11.44
# 4          22.38     86.44      1875.63           10.39           11.26
#
# ...

# %%
print("Columns:")
print(df.columns.tolist())  #total list

print("\nData types:")
print(df.dtypes)  # datatype

print("\nDataset information:")
df.info()  #dataset info

print("\nMissing values:")
print(df.isnull().sum())  #missing value


print("\nDuplicate rows:", df.duplicated().sum())  # Duplicate rows

print("\nStatistical summary:")
display(df.describe(include="all").T)  #statistical summary
# Out:
# Columns:
# ['Soil_Type', 'Soil_pH', 'Soil_Moisture', 'Organic_Carbon', 'Electrical_Conductivity', 'Temperature_C', 'Humidity', 'Rainfall_mm', 'Sunlight_Hours', 'Wind_Speed_kmh', 'Crop_Type', 'Crop_Growth_Stage', 'Season', 'Irrigation_Type', 'Water_Source', 'Field_Area_hectare', 'Mulching_Used', 'Previous_Irrigation_mm', 'Region', 'Irrigation_Need']
#
# Data types:
# Soil_Type                      str
# Soil_pH                    float64
# Soil_Moisture              float64
# Organic_Carbon             float64
# Electrical_Conductivity    float64
# Temperature_C              float64
# Humidity                   float64
# Rainfall_mm                float64
# Sunlight_Hours             float64
# Wind_Speed_kmh             float64
# Crop_Type                      str
# Crop_Growth_Stage              str
# Season                         str
# Irrigation_Type                str
# Water_Source                   str
# Field_Area_hectare         float64
# Mulching_Used                  str
# ...

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

print(df.columns.tolist())  #clean column name
# Out:
# ['soil_type', 'soil_ph', 'soil_moisture', 'organic_carbon', 'electrical_conductivity', 'temperature_c', 'humidity', 'rainfall_mm', 'sunlight_hours', 'wind_speed_kmh', 'crop_type', 'crop_growth_stage', 'season', 'irrigation_type', 'water_source', 'field_area_hectare', 'mulching_used', 'previous_irrigation_mm', 'region', 'irrigation_need']

# %%
print(df["irrigation_need"].value_counts())  #Check the target distribution
# Out:
# irrigation_need
# Low       5864
# Medium    3800
# High       336
# Name: count, dtype: int64

# %%
target_percent = (
    df["irrigation_need"]
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

print(target_percent)   #calculate percentage
# Out:
# irrigation_need
# Low       58.64
# Medium    38.00
# High       3.36
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(7, 5))   #Plot

sns.countplot(
    data=df,
    x="irrigation_need"
)

plt.title("Irrigation Need Distribution")
plt.xlabel("Irrigation Need")
plt.ylabel("Number of Records")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="irrigation_need",
    y="soil_moisture"
)

plt.title("Soil Moisture vs Irrigation Need")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="irrigation_need",
    y="temperature_c"
)

plt.title("Temperature vs Irrigation Need")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="irrigation_need",
    y="rainfall_mm"
)

plt.title("Rainfall vs Irrigation Need")
plt.show()

# %%
plt.figure(figsize=(12, 5))

sns.countplot(
    data=df,
    x="crop_type",
    hue="irrigation_need"
)

plt.xticks(rotation=45)
plt.title("Crop Type vs Irrigation Need")
plt.show()

# %%
plt.figure(figsize=(10, 5))

sns.countplot(
    data=df,
    x="crop_growth_stage",
    hue="irrigation_need"
)

plt.title("Crop Growth Stage vs Irrigation Need")
plt.show()

# %%
numeric_df = df.select_dtypes(
    include=np.number
)

plt.figure(figsize=(12, 8))

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)

plt.title("Numerical Feature Correlation")
plt.show()

# %%
#Create X and y

X = df.drop(
    columns=[
        "irrigation_need",
        "irrigation_type",
        "water_source"
    ]
)

y = df["irrigation_need"]

print("Features:", X.shape)
print("Target:", y.shape)
# Out:
# Features: (10000, 17)
# Target: (10000,)

# %%
#Split the data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training rows:", len(X_train))
print("Testing rows :", len(X_test))
# Out:
# Training rows: 8000
# Testing rows : 2000

# %%
#Create numerical_features and categorical_features

categorical_features = X.select_dtypes(
    include=["object", "category", "bool"]
).columns.tolist()

numerical_features = X.select_dtypes(
    include=np.number
).columns.tolist()

print("Categorical features:")
print(categorical_features)

print("\nNumerical features:")
print(numerical_features)
# Out:
# Categorical features:
# ['soil_type', 'crop_type', 'crop_growth_stage', 'season', 'mulching_used', 'region']
#
# Numerical features:
# ['soil_ph', 'soil_moisture', 'organic_carbon', 'electrical_conductivity', 'temperature_c', 'humidity', 'rainfall_mm', 'sunlight_hours', 'wind_speed_kmh', 'field_area_hectare', 'previous_irrigation_mm']

# %%
#the preprocessing pipeline


from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

numeric_transformer = Pipeline(
    steps=[
        (
            "imputer",
            SimpleImputer(strategy="median")
        )
    ]
)

categorical_transformer = Pipeline(
    steps=[
        (
            "imputer",
            SimpleImputer(strategy="most_frequent")
        ),
        (
            "encoder",
            OneHotEncoder(handle_unknown="ignore")
        )
    ]
)

preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            numeric_transformer,
            numerical_features
        ),
        (
            "cat",
            categorical_transformer,
            categorical_features
        )
    ]
)

print("Preprocessing pipeline created successfully!")
# Out:
# Preprocessing pipeline created successfully!

# %%
#split your dataset

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (8000, 17)
# X_test : (2000, 17)
# y_train: (8000,)
# y_test : (2000,)

# %%
#train Random Forest
from sklearn.ensemble import RandomForestClassifier

rf_model = Pipeline(
    steps=[
        (
            "preprocessor",
            preprocessor
        ),
        (
            "classifier",
            RandomForestClassifier(
                n_estimators=300,
                random_state=42,
                n_jobs=-1,
                class_weight="balanced"
            )
        )
    ]
)

print("Training Random Forest...")

rf_model.fit(
    X_train,
    y_train
)

print("Random Forest training completed!")
# Out:
# Training Random Forest...
# Random Forest training completed!

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Metrics imported successfully!")
# Out:
# Metrics imported successfully!

# %%
# Make predictions
rf_pred = rf_model.predict(X_test)

# Accuracy
rf_accuracy = accuracy_score(y_test, rf_pred)

print("Random Forest Accuracy:", round(rf_accuracy, 4))

# Classification report
print("\nRandom Forest Classification Report")
print("=" * 60)

print(
    classification_report(
        y_test,
        rf_pred,
        labels=["Low", "Medium", "High"],
        digits=4,
        zero_division=0
    )
)
# Out:
# Random Forest Accuracy: 0.987
#
# Random Forest Classification Report
# ...
#               precision    recall  f1-score   support
#
#          Low     0.9974    0.9991    0.9983      1173
#       Medium     0.9705    0.9961    0.9831       760
#         High     1.0000    0.6716    0.8036        67
#
#     accuracy                         0.9870      2000
#    macro avg     0.9893    0.8889    0.9283      2000
# weighted avg     0.9873    0.9870    0.9860      2000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(
    y_test,
    rf_pred,
    labels=["Low", "Medium", "High"]
)

plt.figure(figsize=(7, 5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Low", "Medium", "High"],
    yticklabels=["Low", "Medium", "High"]
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Random Forest Confusion Matrix")

plt.show()

# %%
rf_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['soil_ph', 'soil_moisture',
#                                                    'organic_carbon',
#                                                    'electrical_conductivity',
#                                                    'temperature_c', 'humidity',
#                                                    'rainfall_mm',
#                                                    'sunlight_hours',
#                                                    'wind_speed_kmh',
#                                                    'field_area_hectare',
#                                                    'previous_irrigation_mm']),
# ...

# %%
#Evaluate Random Forest
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

# Predictions
rf_pred = rf_model.predict(X_test)

# Accuracy
rf_accuracy = accuracy_score(y_test, rf_pred)

print("Random Forest Accuracy:", round(rf_accuracy, 4))

# Classification Report
print("\nRandom Forest Classification Report")
print("=" * 60)

print(
    classification_report(
        y_test,
        rf_pred,
        labels=["Low", "Medium", "High"],
        digits=4,
        zero_division=0
    )
)
# Out:
# Random Forest Accuracy: 0.987
#
# Random Forest Classification Report
# ...
#               precision    recall  f1-score   support
#
#          Low     0.9974    0.9991    0.9983      1173
#       Medium     0.9705    0.9961    0.9831       760
#         High     1.0000    0.6716    0.8036        67
#
#     accuracy                         0.9870      2000
#    macro avg     0.9893    0.8889    0.9283      2000
# weighted avg     0.9873    0.9870    0.9860      2000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(
    y_test,
    rf_pred,
    labels=["Low", "Medium", "High"]
)

plt.figure(figsize=(7, 5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Low", "Medium", "High"],
    yticklabels=["Low", "Medium", "High"]
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Random Forest Confusion Matrix")

plt.show()

# %%
from xgboost import XGBClassifier            #Train XGBoost

# Convert target labels
label_mapping = {
    "Low": 0,
    "Medium": 1,
    "High": 2
}

y_encoded = y.map(label_mapping)

# Train/test split
X_train_xgb, X_test_xgb, y_train_xgb, y_test_xgb = train_test_split(
    X,
    y_encoded,
    test_size=0.20,
    random_state=42,
    stratify=y_encoded
)

# XGBoost model
xgb_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "classifier",
            XGBClassifier(
                n_estimators=400,
                learning_rate=0.05,
                max_depth=6,
                subsample=0.8,
                colsample_bytree=0.8,
                objective="multi:softprob",
                num_class=3,
                eval_metric="mlogloss",
                random_state=42,
                n_jobs=-1
            )
        )
    ]
)

print("Training XGBoost...")

xgb_model.fit(
    X_train_xgb,
    y_train_xgb
)

print("XGBoost training completed!")
# Out:
# Training XGBoost...
# XGBoost training completed!

# %%
#Evaluate XGBoost
from sklearn.metrics import accuracy_score, classification_report

xgb_pred = xgb_model.predict(X_test_xgb)

xgb_accuracy = accuracy_score(
    y_test_xgb,
    xgb_pred
)

print("XGBoost Accuracy:", round(xgb_accuracy, 4))

print("\nXGBoost Classification Report")
print("=" * 60)

print(
    classification_report(
        y_test_xgb,
        xgb_pred,
        target_names=["Low", "Medium", "High"],
        digits=4,
        zero_division=0
    )
)
# Out:
# XGBoost Accuracy: 0.997
#
# XGBoost Classification Report
# ...
#               precision    recall  f1-score   support
#
#          Low     0.9991    0.9974    0.9983      1173
#       Medium     0.9948    0.9974    0.9961       760
#         High     0.9851    0.9851    0.9851        67
#
#     accuracy                         0.9970      2000
#    macro avg     0.9930    0.9933    0.9931      2000
# weighted avg     0.9970    0.9970    0.9970      2000

# %%
#Compare macro F1
from sklearn.metrics import f1_score

rf_f1 = f1_score(
    y_test,
    rf_pred,
    average="macro"
)

xgb_f1 = f1_score(
    y_test_xgb,
    xgb_pred,
    average="macro"
)

print("Random Forest Macro F1:", round(rf_f1, 4))
print("XGBoost Macro F1:", round(xgb_f1, 4))
# Out:
# Random Forest Macro F1: 0.9283
# XGBoost Macro F1: 0.9931

# %%
#the XGBoost classification report
from sklearn.metrics import classification_report, accuracy_score

print("XGBoost Accuracy:")
print(round(accuracy_score(y_test_xgb, xgb_pred), 4))

print("\nXGBoost Classification Report")
print("=" * 60)

print(
    classification_report(
        y_test_xgb,
        xgb_pred,
        target_names=["Low", "Medium", "High"],
        digits=4,
        zero_division=0
)
)
# Out:
# XGBoost Accuracy:
# 0.997
#
# XGBoost Classification Report
# ...
#               precision    recall  f1-score   support
#
#          Low     0.9991    0.9974    0.9983      1173
#       Medium     0.9948    0.9974    0.9961       760
#         High     0.9851    0.9851    0.9851        67
#
#     accuracy                         0.9970      2000
#    macro avg     0.9930    0.9933    0.9931      2000
# weighted avg     0.9970    0.9970    0.9970      2000

# %%
#XGBoost as the final model
best_model = xgb_model
best_model_name = "XGBoost"

print("Final Model:", best_model_name)
# Out:
# Final Model: XGBoost

# %%
import os
import joblib

os.makedirs("../models", exist_ok=True)

model_path = "../models/irrigation_need_model.pkl"

joblib.dump(
    best_model,
    model_path
)

print("Model saved successfully!")
print("Path:", model_path)
# Out:
# Model saved successfully!
# Path: ../models/irrigation_need_model.pkl

# %%
loaded_model = joblib.load(
    "../models/irrigation_need_model.pkl"
)

predictions = loaded_model.predict(
    X_test.iloc[:10]
)

print("Predictions:")
print(predictions)
# Out:
# Predictions:
# [1 1 0 1 1 0 1 0 1 0]

# %%
#Convert predictions to actual labels
label_mapping_reverse = {
    0: "Low",
    1: "Medium",
    2: "High"
}

predicted_labels = [
    label_mapping_reverse[int(pred)]
    for pred in predictions
]

print("Predicted irrigation needs:")
print(predicted_labels)
# Out:
# Predicted irrigation needs:
# ['Medium', 'Medium', 'Low', 'Medium', 'Medium', 'Low', 'Medium', 'Low', 'Medium', 'Low']

# %%
# Make the prediction function
def predict_irrigation_need(input_data):
    """
    Predict irrigation need from field data.

    Returns:
        Low / Medium / High
    """

    prediction = loaded_model.predict(input_data)

    label_mapping_reverse = {
        0: "Low",
        1: "Medium",
        2: "High"
    }

    return [
        label_mapping_reverse[int(pred)]
        for pred in prediction
    ]

# %%
#test
result = predict_irrigation_need(
    X_test.iloc[:10]
)

print(result)
# Out:
# ['Medium', 'Medium', 'Low', 'Medium', 'Medium', 'Low', 'Medium', 'Low', 'Medium', 'Low']
